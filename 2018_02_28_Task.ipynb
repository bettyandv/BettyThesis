# %%
import pandas as pd

# %%
data=pd.read_excel('betty_data/AF_AnaforeFeature_betty_processing.xls',sheet_name='Sheet2')

# %%
data.columns=list(map(lambda x: str(x).split(' ')[0],data.columns))

# %%
data=data[:-1]

# %%
data.tail()
# Out:
#       Stkcd  2003-06-30  2003-12-31  2004-06-30  2004-12-31  2005-06-30  \
# 483  002007           0           0           1           0           1
# 484  002008           0           0           1           0           0
# 485  002009           0           0           3           0           0
# 486  002010           0           0           4           2           3
# 487  002011           0           0           1           0           0
#
#      2005-12-31  2006-06-30  2006-12-31  2007-06-30     ...      2015-09-30  \
# 483           4           9           3           2     ...               9
# 484           5           3           4           3     ...               6
# 485           0           1           3           0     ...               5
# 486           4           4           2           0     ...               9
# 487           0           0           0           0     ...               7
#
# ...

# %%
result=pd.DataFrame()
for k,v in data.iterrows():
    stock_df=pd.DataFrame({'Stkcd':v['Stkcd'],'Date':v.index[1:],'Value':v[1:]})
    result=pd.concat((result,stock_df))

# %%
result.to_excel('betty_data/processed_data.xls')
