# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$P(r_a\geq r_e \mid U^\ast_m)=\frac{P(r_a\geq r_e)P(U^\ast_m \mid r_a \geq r_e)}{P(r_a \geq r_e)P(U^\ast_m \mid r_a \geq r_e)+P(r_a < r_e)P(U^{\ast}_m \mid r_a < r_e)}$$
